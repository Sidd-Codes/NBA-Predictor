# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("/Users/siddhantbhatnagar/NBA Predictor/nba_games.csv", index_col = 0)

# %%
df
# Out:
#           mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  39.0   81.0  0.481   6.0  20.0  0.300  14.0  18.0  ...
# 1      240.0  240.0  36.0  100.0  0.360   7.0  31.0  0.226  16.0  19.0  ...
# 2      240.0  240.0  37.0   85.0  0.435   8.0  19.0  0.421  17.0  23.0  ...
# 3      240.0  240.0  41.0   89.0  0.461   8.0  21.0  0.381  17.0  19.0  ...
# 4      240.0  240.0  27.0   86.0  0.314   6.0  26.0  0.231  15.0  20.0  ...
# ...      ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 17767  240.0  240.0  35.0   81.0  0.432  11.0  26.0  0.423  27.0  36.0  ...
# 17768  240.0  240.0  37.0   74.0  0.500  13.0  25.0  0.520  26.0  37.0  ...
# 17769  240.0  240.0  42.0   89.0  0.472  14.0  33.0  0.424  10.0  20.0  ...
# 17770  240.0  240.0  41.0   85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 17771  240.0  240.0  33.0   85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
#
# ...

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
# 1      240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 2      240.0  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  ...
# 3      240.0  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  ...
# 4      240.0  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 17767  240.0  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  ...
# 17768  240.0  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  ...
# 17769  240.0  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  ...
# 17770  240.0  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  ...
# 17771  240.0  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  ...
#
# ...

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df ["index_opp"]

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
# ...

# %%
df_copy = df.copy()

# Define the function to create the target column
def create_target(group):
    return group.shift(-1)

# Create the new target column
new_target = df_copy.groupby("team")["won"].transform(create_target)

# Use pd.concat to join the new column efficiently
df_copy = pd.concat([df_copy, new_target.rename('target')], axis=1)

# %%
phx_data = df_copy[df_copy["team"] == "PHO"]

# %%
phx_data
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 27     240.0  34.0  87.0  0.391   6.0  24.0  0.250  21.0  33.0  0.636  ...
# 57     240.0  37.0  83.0  0.446   4.0  18.0  0.222  32.0  42.0  0.762  ...
# 75     240.0  39.0  94.0  0.415  11.0  32.0  0.344  12.0  16.0  0.750  ...
# 96     240.0  36.0  98.0  0.367   9.0  30.0  0.300  15.0  21.0  0.714  ...
# 128    240.0  45.0  83.0  0.542  14.0  23.0  0.609  14.0  22.0  0.636  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17701  240.0  34.0  76.0  0.447  13.0  28.0  0.464  13.0  15.0  0.867  ...
# 17708  240.0  39.0  84.0  0.464   9.0  25.0  0.360  14.0  18.0  0.778  ...
# 17717  240.0  43.0  87.0  0.494  12.0  32.0  0.375  12.0  16.0  0.750  ...
# 17726  240.0  31.0  78.0  0.397   6.0  18.0  0.333  18.0  21.0  0.857  ...
# 17735  240.0  33.0  87.0  0.379  12.0  34.0  0.353  12.0  18.0  0.667  ...
#
# ...

# %%
df_copy["target"][pd.isnull(df_copy["target"])] = 2

# %%
df_copy["target"] = df_copy["target"].astype(int, errors="ignore")

# %%
df_copy
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
# ...

# %%
df_copy["won"].value_counts()
# Out:
# won
# False    8886
# True     8886
# Name: count, dtype: int64

# %%
df_copy["target"].value_counts()
# Out:
# target
# 1    8872
# 0    8870
# 2      30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df_copy)

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df_copy.columns[~df_copy.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)

# %%
df = df_copy[valid_columns].copy()

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split)

# %%
removed_columns = ["season", "target", "date", "team", "team_opp", "won"]

# %%
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler  = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# ...

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['3p',
#  '3p%',
#  'ft%',
#  'pf',
#  'orb%',
#  'trb%',
#  'tov%',
#  'usg%',
#  'fg_max',
#  'fga_max',
#  '3p_max',
#  'ft_max',
#  'orb_max',
#  'pts_max',
#  '+/-_max',
#  'orb%_max',
#  'trb%_max',
#  'blk%_max',
#  '3p_opp',
#  'ft%_opp',
#  'pts_opp',
#  'drb%_opp',
#  'trb%_opp',
#  'usg%_opp',
#  'blk_max_opp',
#  'pf_max_opp',
#  'pts_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp',
#  'total_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    seasons = sorted(data["season"].unique())
    for i in range(start, len(seasons), step):
        season = seasons[i]
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        model.fit(train[predictors], train["target"])
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#        actual  prediction
# 5490        1           1
# 5496        0           1
# 5511        1           1
# 5515        1           0
# 5516        1           0
# ...       ...         ...
# 17767       0           1
# 17768       1           1
# 17769       0           1
# 17770       2           1
# 17771       2           1
#
# [11172 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5472087596481781

# %%
df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    0.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  tov%_max_opp_10  usg%_max_opp_10  \
# ...

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    0.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  blk%_max_opp  tov%_max_opp  \
# ...

# %%
import pandas as pd

def find_team_avgs(group):
    numeric_cols = group.select_dtypes(include='number')
    rolling = numeric_cols.rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_avgs)

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 251    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 252    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 253    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 256    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100
# 17768  0.0  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736
# 17769  0.0  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572
# 17770  0.0  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710
# 17771  0.0  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812
#
#              ft       fta       ft%  ...  ast%_max_opp  stl%_max_opp  \
# ...

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols
df = pd.concat([df, df_rolling], axis=1)

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    0.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  ast%_max_opp_10  stl%_max_opp_10  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#          mp        fg       fga       fg%        3p       3pa       3p%  \
# 484    0.00  0.409091  0.397059  0.373206  0.206897  0.333333  0.274347
# 506    0.00  0.454545  0.441176  0.392344  0.344828  0.363636  0.423990
# 520    0.00  0.386364  0.279412  0.447368  0.310345  0.409091  0.344418
# 521    0.00  0.477273  0.323529  0.523923  0.482759  0.378788  0.573634
# 527    0.25  0.545455  0.500000  0.449761  0.310345  0.378788  0.368171
# ...     ...       ...       ...       ...       ...       ...       ...
# 17765  0.00  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 17766  0.00  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 17767  0.00  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.00  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.00  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
#
#              ft       fta       ft%  ...  ast%_max_opp_10  stl%_max_opp_10  \
# ...

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")

# %%
df = df.copy()

# %%
full = df.merge(df[rolling_cols + ["team_opp_next", "date_next", "team"]], left_on=["team", "date_next"], right_on=["team_opp_next", "date_next"])

# %%
full
# Out:
#          mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.25  0.545455  0.500000  0.449761  0.310345  0.378788  0.368171
# 1      0.00  0.545455  0.441176  0.500000  0.068966  0.090909  0.237530
# 2      0.00  0.159091  0.264706  0.153110  0.103448  0.151515  0.254157
# 3      0.00  0.409091  0.441176  0.339713  0.241379  0.257576  0.395487
# 4      0.00  0.613636  0.411765  0.607656  0.551724  0.454545  0.559382
# ...     ...       ...       ...       ...       ...       ...       ...
# 13793  0.00  0.250000  0.294118  0.253589  0.517241  0.500000  0.480998
# 13794  0.00  0.386364  0.264706  0.461722  0.517241  0.545455  0.445368
# 13795  0.00  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 13796  0.00  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 13797  0.00  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
#
#              ft       fta       ft%  ...  drtg_max_opp_10_y  \
# ...

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0        DAL             HOU    HOU             DAL  2015-12-04
# 1        MEM             SAS    SAS             MEM  2015-12-03
# 2        MIL             DET    DET             MIL  2015-12-04
# 3        SAS             MEM    MEM             SAS  2015-12-03
# 4        GSW             TOR    TOR             GSW  2015-12-05
# ...      ...             ...    ...             ...         ...
# 13793    BOS             GSW    GSW             BOS  2022-06-08
# 13794    GSW             BOS    BOS             GSW  2022-06-10
# 13795    BOS             GSW    GSW             BOS  2022-06-10
# 13796    GSW             BOS    BOS             GSW  2022-06-13
# 13797    BOS             GSW    GSW             BOS  2022-06-13
#
# [13798 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'target',
#  'date',
#  'team',
#  'team_opp',
#  'won']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]
sfs.fit(full[selected_columns], full["target"])

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['3p',
#  '3p%',
#  'ft%',
#  'pf',
#  'orb%',
#  'trb%',
#  'tov%',
#  'usg%',
#  'fg_max',
#  'fga_max',
#  '3p_max',
#  'ft_max',
#  'orb_max',
#  'pts_max',
#  '+/-_max',
#  'orb%_max',
#  'trb%_max',
#  'blk%_max',
#  '3p_opp',
#  'ft%_opp',
#  'pts_opp',
#  'drb%_opp',
#  'trb%_opp',
#  'usg%_opp',
#  'blk_max_opp',
#  'pf_max_opp',
#  'pts_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp',
#  'total_opp']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5478701406120761
